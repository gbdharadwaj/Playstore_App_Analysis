# %%
import numpy as np
import pandas as pd
import re

# %%
data_reviews=pd.read_csv("E:\Hiiconsoler Project\playstore_reviews.csv")  # ,index_col='App'

# %%
data_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
data_reviews.shape
# Out:
# (64295, 5)

# %%
data_reviews.isnull().sum()
# Out:
# App                           0
# Translated_Review         26868
# Sentiment                 26863
# Sentiment_Polarity        26863
# Sentiment_Subjectivity    26863
# dtype: int64

# %%
# Since there are no translated review so we have to delete the entire row because this kind of data is of no use.
data_reviews=data_reviews.dropna()

# %%
data_reviews.shape
# Out:
# (37427, 5)

# %%
data_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
# Conversion to lower case 
data_reviews["Translated_Review"]=data_reviews["Translated_Review"].str.lower()
data_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  i like eat delicious food. that's i'm cooking ...
# 1  10 Best Foods for You    this help eating healthy exercise regular basis
# 3  10 Best Foods for You         works great especially going grocery store
# 4  10 Best Foods for You                                       best idea us
# 5  10 Best Foods for You                                           best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
# Removing Punctuations and special symbols

# %%
import string
english_punctuations=string.punctuation
punctuations_list=english_punctuations
def cleaning_punctuations(text):
    translator=str.maketrans('','',punctuations_list)
    return text.translate(translator)
data_reviews["Translated_Review"]=data_reviews["Translated_Review"].apply(lambda x: cleaning_punctuations(x))
data_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  i like eat delicious food thats im cooking foo...
# 1  10 Best Foods for You    this help eating healthy exercise regular basis
# 3  10 Best Foods for You         works great especially going grocery store
# 4  10 Best Foods for You                                       best idea us
# 5  10 Best Foods for You                                           best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
english_punctuations=string.punctuation
punctuations_list=english_punctuations
def cleaning_punctuations(text):
    translator=str.maketrans('','',punctuations_list)
    return text.translate(translator)
data_reviews["App"]=data_reviews["App"].apply(lambda x: cleaning_punctuations(x))
data_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  i like eat delicious food thats im cooking foo...
# 1  10 Best Foods for You    this help eating healthy exercise regular basis
# 3  10 Best Foods for You         works great especially going grocery store
# 4  10 Best Foods for You                                       best idea us
# 5  10 Best Foods for You                                           best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)
data_reviews["Translated_Review"]=data_reviews["Translated_Review"].apply(lambda x: remove_emoji(x))
data_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  i like eat delicious food thats im cooking foo...
# 1  10 Best Foods for You    this help eating healthy exercise regular basis
# 3  10 Best Foods for You         works great especially going grocery store
# 4  10 Best Foods for You                                       best idea us
# 5  10 Best Foods for You                                           best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
def remove_emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)
data_reviews["App"]=data_reviews["App"].apply(lambda x: remove_emoji(x))
data_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  i like eat delicious food thats im cooking foo...
# 1  10 Best Foods for You    this help eating healthy exercise regular basis
# 3  10 Best Foods for You         works great especially going grocery store
# 4  10 Best Foods for You                                       best idea us
# 5  10 Best Foods for You                                           best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
# Removing URLs from the data

# %%
def cleaning_URLs(data):
    return re.sub('((www.[^s]+)|(https?://[^s]+))','',data)
data_reviews["Translated_Review"]=data_reviews["Translated_Review"].apply(lambda x: cleaning_URLs(x))
data_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  i like eat delicious food thats im cooking foo...
# 1  10 Best Foods for You    this help eating healthy exercise regular basis
# 3  10 Best Foods for You         works great especially going grocery store
# 4  10 Best Foods for You                                       best idea us
# 5  10 Best Foods for You                                           best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
# Removing numbers

# %%
def cleaning_numbers(data):
    return re.sub('[0-9]+','',data)
data_reviews["Translated_Review"]=data_reviews["Translated_Review"].apply(lambda x: cleaning_numbers(x))
data_reviews.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  i like eat delicious food thats im cooking foo...
# 1  10 Best Foods for You    this help eating healthy exercise regular basis
# 3  10 Best Foods for You         works great especially going grocery store
# 4  10 Best Foods for You                                       best idea us
# 5  10 Best Foods for You                                           best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
# Saving the dataframe
data_reviews.to_csv("reviews_csv")
